# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# ## __REGINALD ANDREW SAI-OBODAI__

# %% [markdown]
# ### Machine Learning Engineer

# %% [markdown]
# _I am interest in data science because I want to pursue a career in robotics and artificial intelligence_

# %% [markdown]
# ### ADDITION IN JUPYTER

# %%
1+1
# Out:
# 2

# %% [markdown]
# - orange
# - mango
# - pear

# %% [markdown]
# 1. book
# 2. pen
# 3. eraser

# %% [markdown]
# this is the text above the horizonatal rule
#
# ***
# this is the text below the horizontal rule
